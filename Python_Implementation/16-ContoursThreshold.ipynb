# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image and get it as greyscale
image = cv2.imread("./images/shapes.jpg")

# Check if the image is loaded
if image is None:
    print(" Error: Can't load the image")
else:
    print("Image Loaded Successfully.")

# Conver the image to grey
img_grey = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# 1. Thresholding to get binary image, use the maximum colors range values you want to see (240)
retval, binary = cv2.threshold(img_grey, 240, 255, cv2.THRESH_BINARY)

plt.imshow(binary, cmap='grey')

# if you want to remove other colored shapes change for ex: 150
retval, binary = cv2.threshold(img_grey, 150, 255, cv2.THRESH_BINARY)

plt.imshow(binary, cmap='grey')
# Out:
# Image Loaded Successfully.
